# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# Goal: find out which types of games are most likely rated favorably by users.
# ex. early access, free-to-play, M-rated, T-rated, E-rated, genres, etc
#
# What are some common things that users write about in their reviews?
# ex. gameplay, story, sound, graphics, buisness strategy, etc

# %%
df_test = pd.read_csv("./test_gr/test.csv")
df_train = pd.read_csv("./train_gr/train.csv")
df_overview = pd.read_csv("./train_gr/game_overview.csv")
df_train.head()
# Out:
#    review_id                        title    year  \
# 0          1  Spooky's Jump Scare Mansion  2016.0
# 1          2  Spooky's Jump Scare Mansion  2016.0
# 2          3  Spooky's Jump Scare Mansion  2016.0
# 3          4  Spooky's Jump Scare Mansion  2015.0
# 4          5  Spooky's Jump Scare Mansion  2015.0
#
#                                          user_review  user_suggestion
# 0  I'm scared and hearing creepy voices.  So I'll...                1
# 1  Best game, more better than Sam Pepper's YouTu...                1
# 2  A littly iffy on the controls, but once you kn...                1
# 3  Great game, fun and colorful and all that.A si...                1
# 4  Not many games have the cute tag right next to...                1

# %%
df_train.describe()
# Out:
#           review_id          year  user_suggestion
# count  17494.000000  17316.000000     17494.000000
# mean   12423.216989   2016.388427         0.569795
# std     7653.367660      1.390356         0.495119
# min        1.000000   2011.000000         0.000000
# 25%     5769.250000   2015.000000         0.000000
# 50%    11756.500000   2017.000000         1.000000
# 75%    18926.750000   2018.000000         1.000000
# max    25539.000000   2018.000000         1.000000

# %%
df_filtered = df_train[df_train["title"] == "Sakura Clicker"]
df_filtered.head()
# Out:
#      review_id           title    year  \
# 362        363  Sakura Clicker  2015.0
# 363        364  Sakura Clicker  2015.0
# 364        365  Sakura Clicker  2016.0
# 365        366  Sakura Clicker  2018.0
# 366        367  Sakura Clicker  2016.0
#
#                                            user_review  user_suggestion
# 362  First of all I must say the plot is amazing. I...                1
# 363  Sublimely Magnificent game which put your mind...                1
# 364  It's free & 'amusing,' but it's arguably one o...                0
# 365  Sakura clicker is a game where you click on th...                1
# 366  I disappointed my family..my dad punched me al...                1

# %%
genre = []
#iterate through tags column and concat into a single dataframe
for i, row in df_overview["tags"].items():
    df = row.replace("[", "").replace("]", "").replace("'", "")
    df_overview["tags"][i] = df
    genre = genre + df.split(", ")
df_genre = pd.DataFrame(data=genre)
#df_overview["tags"].head()
df_genre.value_counts()
# Out:
# Free to Play             63
# Multiplayer              61
# Action                   54
# Massively Multiplayer    48
# Co-op                    42
#                          ..
# City Builder              1
# Side Scroller             1
# Cartoony                  1
# Cartoon                   1
# Real-Time                 1
# Name: count, Length: 161, dtype: int64

# %% [markdown]
# TODO: combine df_train and genre so that title is matched with correct genre

# %%
d = df_train.groupby([df_train["title"]], as_index=False).agg({"user_suggestion": "mean"}).sort_values(by="user_suggestion", ascending=False)
#genre_df = df.groupby([df_train["title"], df_overview["tags"]]).agg({"user_suggestion": "mean"})
#genre_df.columns = ["user_suggestion_mean"]
#genre_df = genre_df.reset_index()
d
# Out:
#                                                 title  user_suggestion
# 14                                       EverQuest II         0.971014
# 16                                    Fractured Space         0.958217
# 21                                      Path of Exile         0.906114
# 6                                         Creativerse         0.900407
# 22                                       PlanetSide 2         0.896186
# 34                     Tactical Monsters Rumble Arena         0.894737
# 33                        Spooky's Jump Scare Mansion         0.886740
# 27                                    Ring of Elysium         0.875895
# 4                                          Brawlhalla         0.865854
# 32                                        Shop Heroes         0.865385
# 24                                      Realm Grinder         0.864516
# 1                                         Black Squad         0.861111
# 30                                     Sakura Clicker         0.819820
# 9                             DCS World Steam Edition         0.807377
# 26                               Realm of the Mad God         0.802941
# 35                                    Team Fortress 2         0.762004
# 11                                        Dreadnought         0.716667
# 12                                            Elsword         0.687135
# 29                                             SMITE®         0.678414
# 40                     World of Guns: Gun Disassembly         0.658703
# 13                                  Eternal Card Game         0.625790
# 25                                       Realm Royale         0.624434
# 36                       The Elder Scrolls®: Legends™         0.610619
# 15                                    Fallout Shelter         0.601790
# 7                         Crusaders of the Lost Idols         0.583333
# 0                                   AdventureQuest 3D         0.572254
# 20                                        Neverwinter         0.569597
# 17                     Freestyle 2: Street Basketball         0.561404
# 38                                            WARMODE         0.530000
# 10                                             Dota 2         0.501235
# 31                                  School of Dragons         0.492537
# 41                               World of Tanks Blitz         0.492355
# 5   Business Tour - Board Game with Online Multipl...         0.481675
# 42                               Yu-Gi-Oh! Duel Links         0.473684
# 23                         RaceRoom Racing Experience         0.466346
# 37                                              Trove         0.453488
# 43                                  theHunter Classic         0.444015
# 3                                   Bloons TD Battles         0.412017
# 8                                      Cuisine Royale         0.375940
# 19                             Infestation: The New Z         0.269311
# 2                                        Bless Online         0.212079
# 39                                        War Thunder         0.169444
# 18                                  Heroes & Generals         0.110067
# 28                                          Robocraft         0.057007

# %%
match_df = d["title"].isin(df_overview["title"])
d["tags"] = np.nan
for i, row in d.iterrows():
    s = row["title"]
    tag = df_overview.loc[df_overview["title"] == s]
    d["tags"][i] = tag["tags"].item()
d
# Out:
# C:\Users\dylan\AppData\Local\Temp\ipykernel_9984\1064366843.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d["tags"][i] = tag["tags"].item()
# C:\Users\dylan\AppData\Local\Temp\ipykernel_9984\1064366843.py:6: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Free to Play, Massively Multiplayer, RPG, MMORPG, Fantasy, Crafting, Open World, Adventure, Exploration, Multiplayer, Action, Character Customization, Singleplayer, Classic, Sandbox, FPS' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   d["tags"][i] = tag["tags"].item()
#                                                 title  user_suggestion  \
# 14                                       EverQuest II         0.971014
# 16                                    Fractured Space         0.958217
# 21                                      Path of Exile         0.906114
# 6                                         Creativerse         0.900407
# 22                                       PlanetSide 2         0.896186
# 34                     Tactical Monsters Rumble Arena         0.894737
# 33                        Spooky's Jump Scare Mansion         0.886740
# 27                                    Ring of Elysium         0.875895
# 4                                          Brawlhalla         0.865854
# 32                                        Shop Heroes         0.865385
# 24                                      Realm Grinder         0.864516
# 1                                         Black Squad         0.861111
# 30                                     Sakura Clicker         0.819820
# 9                             DCS World Steam Edition         0.807377
# 26                               Realm of the Mad God         0.802941
# 35                                    Team Fortress 2         0.762004
# 11                                        Dreadnought         0.716667
# 12                                            Elsword         0.687135
# 29                                             SMITE®         0.678414
# 40                     World of Guns: Gun Disassembly         0.658703
# 13                                  Eternal Card Game         0.625790
# 25                                       Realm Royale         0.624434
# 36                       The Elder Scrolls®: Legends™         0.610619
# 15                                    Fallout Shelter         0.601790
# 7                         Crusaders of the Lost Idols         0.583333
# 0                                   AdventureQuest 3D         0.572254
# 20                                        Neverwinter         0.569597
# 17                     Freestyle 2: Street Basketball         0.561404
# 38                                            WARMODE         0.530000
# 10                                             Dota 2         0.501235
# 31                                  School of Dragons         0.492537
# 41                               World of Tanks Blitz         0.492355
# 5   Business Tour - Board Game with Online Multipl...         0.481675
# 42                               Yu-Gi-Oh! Duel Links         0.473684
# 23                         RaceRoom Racing Experience         0.466346
# 37                                              Trove         0.453488
# 43                                  theHunter Classic         0.444015
# 3                                   Bloons TD Battles         0.412017
# 8                                      Cuisine Royale         0.375940
# 19                             Infestation: The New Z         0.269311
# 2                                        Bless Online         0.212079
# 39                                        War Thunder         0.169444
# 18                                  Heroes & Generals         0.110067
# 28                                          Robocraft         0.057007
#
#                                                  tags
# 14  Free to Play, Massively Multiplayer, RPG, MMOR...
# 16  Space, Multiplayer, Free to Play, PvP, MOBA, A...
# 21  Free to Play, Action RPG, Hack and Slash, RPG,...
# 6   Free to Play, Survival, Open World, Multiplaye...
# 22  Free to Play, Massively Multiplayer, FPS, Shoo...
# 34  Free to Play, Strategy, Multiplayer, Turn-Base...
# 33  Horror, Free to Play, Cute, First-Person, Sing...
# 27  Early Access, Free to Play, Battle Royale, Sho...
# 4   Free to Play, Multiplayer, Fighting, 2D, 2D Fi...
# 32  Free to Play, Simulation, Casual, Strategy, RP...
# 24  Free to Play, Clicker, Strategy, RPG, City Bui...
# 1   Early Access, Free to Play, FPS, Multiplayer, ...
# 30  Nudity, Anime, Free to Play, Mature, Sexual Co...
# 9   Simulation, Flight, Free to Play, Military, Mu...
# 26  Free to Play, Massively Multiplayer, Pixel Gra...
# 35  Free to Play, Multiplayer, FPS, Action, Shoote...
# 11  Free to Play, Space, Action, Massively Multipl...
# 12  Free to Play, Anime, RPG, Action, MMORPG, Adve...
# 29  Free to Play, MOBA, Multiplayer, Action, Third...
# 40  Free to Play, Simulation, Shooter, Gun Customi...
# 13  Free to Play, Card Game, Strategy, Trading Car...
# 25  Early Access, Battle Royale, Free to Play, Mul...
# 36  Free to Play, Card Game, Multiplayer, Strategy...
# 15  Free to Play, Survival, Base Building, Post-ap...
# 7   Free to Play, Clicker, Casual, Indie, Funny, Z...
# 0   Early Access, Free to Play, RPG, Massively Mul...
# 20  Free to Play, MMORPG, RPG, Massively Multiplay...
# 17  Free to Play, Basketball, Sports, Multiplayer,...
# 38  Early Access, Free to Play, FPS, Multiplayer, ...
# 10  Free to Play, MOBA, Strategy, Multiplayer, Tea...
# 31  Free to Play, Dragons, Adventure, Multiplayer,...
# 41  Tanks, Free to Play, Multiplayer, Action, Worl...
# 5   Free to Play, Board Game, Strategy, Massively ...
# 42  Free to Play, Card Game, Anime, Multiplayer, S...
# 23  Racing, Free to Play, Multiplayer, Simulation,...
# 37  Free to Play, Open World, Multiplayer, Adventu...
# 43  Free to Play, Hunting, Multiplayer, Open World...
# 3   Free to Play, Tower Defense, Multiplayer, Stra...
# 8   Early Access, Free to Play, Battle Royale, Sur...
# 19  Zombies, Free to Play, Survival, Multiplayer, ...
# 2   MMORPG, Open World, Massively Multiplayer, RPG...
# 39  Free to Play, World War II, Multiplayer, Simul...
# 18  Free to Play, World War II, Multiplayer, FPS, ...
# 28  Free to Play, Robots, Building, Multiplayer, A...

# %%
df_filtered["user_suggestion"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='user_suggestion'>

# %%
sns.barplot(data=d[:5], x="title", y="user_suggestion", hue="title")
# Out:
# <Axes: xlabel='title', ylabel='user_suggestion'>

# %% [markdown]
# TODO:
# From here the data can be further broken down into the genres of each game plotted against the user suggestion.

# %%
sample_fps = d[d["tags"].str.contains("FPS", case=False)]
sample_co = d[d["tags"].str.contains("Co-op", case=False)]
sample_horror = d[d["tags"].str.contains("Horror", case=False)]

# %%
sns.barplot(data=sample_horror[:3], x="title", y="user_suggestion", hue="title")
# Out:
# <Axes: xlabel='title', ylabel='user_suggestion'>

# %%
example = pd.DataFrame({
    "title": ["spooky's jump scare mansion", "team fortress 2", "counter strike", "Cuisine Royale"],
    "tags": ["Horror", "FPS", "FPS", "Horror"],
    "user_suggestion_mean": [0.653378, 0.876493, 0.824256, 0.528754]
})

# %%
sns.barplot(data=example, x="tags", y="user_suggestion_mean", hue="tags")
# Out:
# <Axes: xlabel='tags', ylabel='user_suggestion_mean'>
